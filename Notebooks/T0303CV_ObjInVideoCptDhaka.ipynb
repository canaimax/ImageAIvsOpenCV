# %% [markdown]
# Gus Marquez IS687
#
# Captain's OpenCV Object Detection in Video
#
# (Help for these code can be found in OpenCV, YOLO and PYImageSearch)
#
# Google Drive Mounted /content/drive/MyDrive/colab/
#
# LOAD LIBRARIES and SETUP

# %%
pip install imutils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imutils in /usr/local/lib/python3.7/dist-packages (0.5.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# SETUP

# %%
import numpy as np
import time
import calendar
import cv2
import imutils
from imutils.video import FPS
from imutils.video import VideoStream

#  Google Drive Paths

INPUT_FILE='/content/drive/MyDrive/colab/dhaka_traffic_m.mp4'
OUTPUT_FILE='/content/drive/MyDrive/colab/detectdhakacv303.avi'
LABELS_FILE='/content/drive/MyDrive/colab/coco.names'
CONFIG_FILE='/content/drive/MyDrive/colab/yolov3.cfg'
WEIGHTS_FILE='/content/drive/MyDrive/colab/yolov3.weights'
CONFIDENCE_THRESHOLD=0.3

#  Set high, width, timer, writer, labels, color, darknet, video capture
#   And all my counters / accumulators
#    (cc) counting counter, (conf) confidence, 
#     Now...  (plot) the value for plotting later and tranfered via drive to ImageAI



# Video Capture abd boxes
H=None
W=None
fourcc = cv2.VideoWriter_fourcc(*"MJPG")
writer = cv2.VideoWriter(OUTPUT_FILE, fourcc, 30,
	(800, 600), True)
LABELS = open(LABELS_FILE).read().strip().split("\n")
# 42, Captain's meaning of life
np.random.seed(42)
COLORS = np.random.randint(0, 255, size=(len(LABELS), 3),
	dtype="uint8")
net = cv2.dnn.readNetFromDarknet(CONFIG_FILE, WEIGHTS_FILE)
vs = cv2.VideoCapture(INPUT_FILE)
ln = [layer_name for layer_name in net.getUnconnectedOutLayersNames()]

# Counters/Accumulators 
cnt =0;
carcc = 0; carconf = 0; carplot = []
personcc = 0; personconf = 0; personplot = []
motorbikecc = 0; motorbikeconf = 0; motorbikeplot = []
truckcc = 0; truckconf = 0; truckplot = []
FRAMENUM = 0
tt = 0

# %%
#SET TIMER
# this timer for CV is the same for AI
current_GMT = time.gmtime()
time_stamp_start = calendar.timegm(current_GMT)
print("Current timestamp:", time_stamp_start)
fps = FPS().start()
# Begin detection/boxes

while True:
	cnt+=1
	print ("Frames so far", cnt)
	try:
		(grabbed, image) = vs.read()
	except:
		break
	blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416),
		swapRB=True, crop=False)

	net.setInput(blob)
	if W is None or H is None:
		(H, W) = image.shape[:2]
	layerOutputs = net.forward(ln)
	if cnt == 291:
		break

	# initialize our lists of detected bounding boxes, confidences, and
	# class IDs, respectively
	boxes = []
	confidences = []
	classIDs = []

	print("#################################################################")
	# LOOPS LAYERS
	for output in layerOutputs:
		#print("OUTPUT >>>>>> ", output)
		# LOOPS DETECTION
		for detection in output:
			#CLASSID / SCORE
			scores = detection[5:]
			classID = np.argmax(scores)
			confidence = scores[classID]
			tt = confidence
			#print("$$$$$$$$$$$$$$$$", FRAMENUM, tt, "$$$$$$$$$$$$$")

			#FILTER
			if confidence > CONFIDENCE_THRESHOLD:
				# BOX
				box = detection[0:4] * np.array([W, H, W, H])
				(centerX, centerY, width, height) = box.astype("int")
				# BOX BOUND
				x = int(centerX - (width / 2))
				y = int(centerY - (height / 2))
				# APPEND
				boxes.append([x, y, int(width), int(height)])
				confidences.append(float(confidence))
				classIDs.append(classID)
		
				#print("$$$$$$$$$$$$$$$$", FRAMENUM, classID, confidence, "$$$$$$$$$$$$$")

	# NMS
	idxs = cv2.dnn.NMSBoxes(boxes, confidences, CONFIDENCE_THRESHOLD,
		CONFIDENCE_THRESHOLD)


	#DETECTION
	if len(idxs) > 0:
		for i in idxs.flatten():
			FRAMENUM = FRAMENUM + 1
			#print("FRAMENUM = :", FRAMENUM)
			#print("IIIIIIIIIII", i)
			# BOX COORDS
			(x, y) = (boxes[i][0], boxes[i][1])
			(w, h) = (boxes[i][2], boxes[i][3])
			#print("$$$$$$$$$$$$$$$$", FRAMENUM, classID, confidence, "$$$$$$$$$$$$$")
			color = [int(c) for c in COLORS[classIDs[i]]]
			cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
			text = "{}: {:.4f}".format(LABELS[classIDs[i]], confidences[i])
			#print("..........", classIDs[i], "..............TEXT", text)
			cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,
				0.5, color, 2)
			#print("TEXT = " , text)
			#CURRENT REPORT...
			#print("This frame", LABELS[classIDs[i]], confidences[i])
	 		# NOW HERE THE COUNTERS/ACCUMULATORS
			if LABELS[classIDs[i]] == "car":
				carcc = carcc + 1
				carconf = carconf + confidences[i]
				carplot.append(confidences[i])
			if LABELS[classIDs[i]] == "person":
				personcc = personcc + 1
				personconf = personconf + confidences[i]
				personplot.append(confidences[i])
			if LABELS[classIDs[i]] == "motorbike":
				motorbikecc = motorbikecc + 1
				motorbikeconf = motorbikeconf + confidences[i]
				motorbikeplot.append(confidences[i])
			if LABELS[classIDs[i]] == "truck":
				truckcc = truckcc + 1
				truckconf = truckconf + confidences[i]
				truckplot.append(confidences[i])
			#print("///////////////////////////Cars = ", carcc, " Confidences = ", carconf)
			#print("CONF = ", confidences[i])

			#print("Persons = ", personcc, " Confidences = ", personconf)
			#print("CONF = ", confidences[i])
	 
			#print("Motorbikes = ", motorbikecc, " Confidences = ", motorbikeconf)
			#print("CONF = ", confidences[i])

			#print("Trucks = ", truckcc, " Confidences = ", truckconf)
			#print("CONF = ", confidences[i])

	#ENDING LOOP LAYEROUTPUT
	#cv2.imshow(cv2.resize(image,(800, 600)))
	writer.write(cv2.resize(image,(800, 600)))
	fps.update()
	#print("[INFO] elasped time: {:.2f}".format(fps.elapsed()))
	#print("[INFO] approx. FPS: {:.2f}".format(fps.fps()))
	key = cv2.waitKey(1) & 0xFF
	if key == ord("q"):
		break



#TOTALS........

# TIMER
current_GMT = time.gmtime()
time_stamp_end = calendar.timegm(current_GMT)
print("Start:", time_stamp_start)
print("End:", time_stamp_end)
print("Time:", time_stamp_end - time_stamp_start)


fps.stop()

# REPORTS

print("[INFO] elasped time: {:.2f}".format(fps.elapsed()))
print("[INFO] approx. FPS: {:.2f}".format(fps.fps()))

print("Cars = ", carcc, " Confidences = ", carconf, " Cars average confidence = " , carconf/carcc)

print("Persons = ", personcc, " Confidences = ", personconf, " Persons average confidence = " , personconf/personcc)

print("Motorbikes = ", motorbikecc, " Confidences = ", motorbikeconf, " Motobikes average confidence = " , motorbikeconf/motorbikecc)

print("Trucks = ", truckcc, " Confidences = ", truckconf, " Trucks average confidence = " , truckconf/truckcc)

# do a bit of cleanup
cv2.destroyAllWindows()

# release the file pointers
print("[INFO] cleaning up...")
writer.release()
vs.release()
# Out:
# Current timestamp: 1662889197
# Frames so far 1
# #################################################################
# Frames so far 2
# #################################################################
# Frames so far 3
# #################################################################
# Frames so far 4
# #################################################################
# Frames so far 5
# #################################################################
# Frames so far 6
# #################################################################
# Frames so far 7
# #################################################################
# Frames so far 8
# #################################################################
# Frames so far 9
# #################################################################
# Frames so far 10
# #################################################################
# Frames so far 11
# #################################################################
# Frames so far 12
# #################################################################
# Frames so far 13
# #################################################################
# Frames so far 14
# #################################################################
# Frames so far 15
# #################################################################
# Frames so far 16
# #################################################################
# Frames so far 17
# #################################################################
# Frames so far 18
# #################################################################
# Frames so far 19
# #################################################################
# Frames so far 20
# #################################################################
# Frames so far 21
# #################################################################
# Frames so far 22
# #################################################################
# Frames so far 23
# #################################################################
# Frames so far 24
# #################################################################
# Frames so far 25
# #################################################################
# Frames so far 26
# #################################################################
# Frames so far 27
# #################################################################
# Frames so far 28
# #################################################################
# Frames so far 29
# #################################################################
# Frames so far 30
# #################################################################
# Frames so far 31
# #################################################################
# Frames so far 32
# #################################################################
# Frames so far 33
# #################################################################
# Frames so far 34
# #################################################################
# Frames so far 35
# #################################################################
# Frames so far 36
# #################################################################
# Frames so far 37
# #################################################################
# Frames so far 38
# #################################################################
# Frames so far 39
# #################################################################
# Frames so far 40
# #################################################################
# Frames so far 41
# #################################################################
# Frames so far 42
# #################################################################
# Frames so far 43
# #################################################################
# Frames so far 44
# #################################################################
# Frames so far 45
# #################################################################
# Frames so far 46
# #################################################################
# Frames so far 47
# #################################################################
# Frames so far 48
# #################################################################
# Frames so far 49
# #################################################################
# Frames so far 50
# #################################################################
# Frames so far 51
# #################################################################
# Frames so far 52
# #################################################################
# Frames so far 53
# #################################################################
# Frames so far 54
# #################################################################
# Frames so far 55
# #################################################################
# Frames so far 56
# #################################################################
# Frames so far 57
# #################################################################
# Frames so far 58
# #################################################################
# Frames so far 59
# #################################################################
# Frames so far 60
# #################################################################
# Frames so far 61
# #################################################################
# Frames so far 62
# #################################################################
# Frames so far 63
# #################################################################
# Frames so far 64
# #################################################################
# Frames so far 65
# #################################################################
# Frames so far 66
# #################################################################
# Frames so far 67
# #################################################################
# Frames so far 68
# #################################################################
# Frames so far 69
# #################################################################
# Frames so far 70
# #################################################################
# Frames so far 71
# #################################################################
# Frames so far 72
# #################################################################
# Frames so far 73
# #################################################################
# Frames so far 74
# #################################################################
# Frames so far 75
# #################################################################
# Frames so far 76
# #################################################################
# Frames so far 77
# #################################################################
# Frames so far 78
# #################################################################
# Frames so far 79
# #################################################################
# Frames so far 80
# #################################################################
# Frames so far 81
# #################################################################
# Frames so far 82
# #################################################################
# Frames so far 83
# #################################################################
# Frames so far 84
# #################################################################
# Frames so far 85
# #################################################################
# Frames so far 86
# #################################################################
# Frames so far 87
# #################################################################
# Frames so far 88
# #################################################################
# Frames so far 89
# #################################################################
# Frames so far 90
# #################################################################
# Frames so far 91
# #################################################################
# Frames so far 92
# #################################################################
# Frames so far 93
# #################################################################
# Frames so far 94
# #################################################################
# Frames so far 95
# #################################################################
# Frames so far 96
# #################################################################
# Frames so far 97
# #################################################################
# Frames so far 98
# #################################################################
# Frames so far 99
# #################################################################
# Frames so far 100
# #################################################################
# Frames so far 101
# #################################################################
# Frames so far 102
# #################################################################
# Frames so far 103
# #################################################################
# Frames so far 104
# #################################################################
# Frames so far 105
# #################################################################
# Frames so far 106
# #################################################################
# Frames so far 107
# #################################################################
# Frames so far 108
# #################################################################
# Frames so far 109
# #################################################################
# Frames so far 110
# #################################################################
# Frames so far 111
# #################################################################
# Frames so far 112
# #################################################################
# Frames so far 113
# #################################################################
# Frames so far 114
# #################################################################
# Frames so far 115
# #################################################################
# Frames so far 116
# #################################################################
# Frames so far 117
# #################################################################
# Frames so far 118
# #################################################################
# Frames so far 119
# #################################################################
# Frames so far 120
# #################################################################
# Frames so far 121
# #################################################################
# Frames so far 122
# #################################################################
# Frames so far 123
# #################################################################
# Frames so far 124
# #################################################################
# Frames so far 125
# #################################################################
# Frames so far 126
# #################################################################
# Frames so far 127
# #################################################################
# Frames so far 128
# #################################################################
# Frames so far 129
# #################################################################
# Frames so far 130
# #################################################################
# Frames so far 131
# #################################################################
# Frames so far 132
# #################################################################
# Frames so far 133
# #################################################################
# Frames so far 134
# #################################################################
# Frames so far 135
# #################################################################
# Frames so far 136
# #################################################################
# Frames so far 137
# #################################################################
# Frames so far 138
# #################################################################
# Frames so far 139
# #################################################################
# Frames so far 140
# #################################################################
# Frames so far 141
# #################################################################
# Frames so far 142
# #################################################################
# Frames so far 143
# #################################################################
# Frames so far 144
# #################################################################
# Frames so far 145
# #################################################################
# Frames so far 146
# #################################################################
# Frames so far 147
# #################################################################
# Frames so far 148
# #################################################################
# Frames so far 149
# #################################################################
# Frames so far 150
# #################################################################
# Frames so far 151
# #################################################################
# Frames so far 152
# #################################################################
# Frames so far 153
# #################################################################
# Frames so far 154
# #################################################################
# Frames so far 155
# #################################################################
# Frames so far 156
# #################################################################
# Frames so far 157
# #################################################################
# Frames so far 158
# #################################################################
# Frames so far 159
# #################################################################
# Frames so far 160
# #################################################################
# Frames so far 161
# #################################################################
# Frames so far 162
# #################################################################
# Frames so far 163
# #################################################################
# Frames so far 164
# #################################################################
# Frames so far 165
# #################################################################
# Frames so far 166
# #################################################################
# Frames so far 167
# #################################################################
# Frames so far 168
# #################################################################
# Frames so far 169
# #################################################################
# Frames so far 170
# #################################################################
# Frames so far 171
# #################################################################
# Frames so far 172
# #################################################################
# Frames so far 173
# #################################################################
# Frames so far 174
# #################################################################
# Frames so far 175
# #################################################################
# Frames so far 176
# #################################################################
# Frames so far 177
# #################################################################
# Frames so far 178
# #################################################################
# Frames so far 179
# #################################################################
# Frames so far 180
# #################################################################
# Frames so far 181
# #################################################################
# Frames so far 182
# #################################################################
# Frames so far 183
# #################################################################
# Frames so far 184
# #################################################################
# Frames so far 185
# #################################################################
# Frames so far 186
# #################################################################
# Frames so far 187
# #################################################################
# Frames so far 188
# #################################################################
# Frames so far 189
# #################################################################
# Frames so far 190
# #################################################################
# Frames so far 191
# #################################################################
# Frames so far 192
# #################################################################
# Frames so far 193
# #################################################################
# Frames so far 194
# #################################################################
# Frames so far 195
# #################################################################
# Frames so far 196
# #################################################################
# Frames so far 197
# #################################################################
# Frames so far 198
# #################################################################
# Frames so far 199
# #################################################################
# Frames so far 200
# #################################################################
# Frames so far 201
# #################################################################
# Frames so far 202
# #################################################################
# Frames so far 203
# #################################################################
# Frames so far 204
# #################################################################
# Frames so far 205
# #################################################################
# Frames so far 206
# #################################################################
# Frames so far 207
# #################################################################
# Frames so far 208
# #################################################################
# Frames so far 209
# #################################################################
# Frames so far 210
# #################################################################
# Frames so far 211
# #################################################################
# Frames so far 212
# #################################################################
# Frames so far 213
# #################################################################
# Frames so far 214
# #################################################################
# Frames so far 215
# #################################################################
# Frames so far 216
# #################################################################
# Frames so far 217
# #################################################################
# Frames so far 218
# #################################################################
# Frames so far 219
# #################################################################
# Frames so far 220
# #################################################################
# Frames so far 221
# #################################################################
# Frames so far 222
# #################################################################
# Frames so far 223
# #################################################################
# Frames so far 224
# #################################################################
# Frames so far 225
# #################################################################
# Frames so far 226
# #################################################################
# Frames so far 227
# #################################################################
# Frames so far 228
# #################################################################
# Frames so far 229
# #################################################################
# Frames so far 230
# #################################################################
# Frames so far 231
# #################################################################
# Frames so far 232
# #################################################################
# Frames so far 233
# #################################################################
# Frames so far 234
# #################################################################
# Frames so far 235
# #################################################################
# Frames so far 236
# #################################################################
# Frames so far 237
# #################################################################
# Frames so far 238
# #################################################################
# Frames so far 239
# #################################################################
# Frames so far 240
# #################################################################
# Frames so far 241
# #################################################################
# Frames so far 242
# #################################################################
# Frames so far 243
# #################################################################
# Frames so far 244
# #################################################################
# Frames so far 245
# #################################################################
# Frames so far 246
# #################################################################
# Frames so far 247
# #################################################################
# Frames so far 248
# #################################################################
# Frames so far 249
# #################################################################
# Frames so far 250
# #################################################################
# Frames so far 251
# #################################################################
# Frames so far 252
# #################################################################
# Frames so far 253
# #################################################################
# Frames so far 254
# #################################################################
# Frames so far 255
# #################################################################
# Frames so far 256
# #################################################################
# Frames so far 257
# #################################################################
# Frames so far 258
# #################################################################
# Frames so far 259
# #################################################################
# Frames so far 260
# #################################################################
# Frames so far 261
# #################################################################
# Frames so far 262
# #################################################################
# Frames so far 263
# #################################################################
# Frames so far 264
# #################################################################
# Frames so far 265
# #################################################################
# Frames so far 266
# #################################################################
# Frames so far 267
# #################################################################
# Frames so far 268
# #################################################################
# Frames so far 269
# #################################################################
# Frames so far 270
# #################################################################
# Frames so far 271
# #################################################################
# Frames so far 272
# #################################################################
# Frames so far 273
# #################################################################
# Frames so far 274
# #################################################################
# Frames so far 275
# #################################################################
# Frames so far 276
# #################################################################
# Frames so far 277
# #################################################################
# Frames so far 278
# #################################################################
# Frames so far 279
# #################################################################
# Frames so far 280
# #################################################################
# Frames so far 281
# #################################################################
# Frames so far 282
# #################################################################
# Frames so far 283
# #################################################################
# Frames so far 284
# #################################################################
# Frames so far 285
# #################################################################
# Frames so far 286
# #################################################################
# Frames so far 287
# #################################################################
# Frames so far 288
# #################################################################
# Frames so far 289
# #################################################################
# Frames so far 290
# #################################################################
# Frames so far 291
# Start: 1662889197
# End: 1662889557
# Time: 360
# [INFO] elasped time: 359.82
# [INFO] approx. FPS: 0.81
# Cars =  450  Confidences =  347.7934652864933  Cars average confidence =  0.7728743673033185
# Persons =  1881  Confidences =  1184.6036169826984  Persons average confidence =  0.6297733210965967
# Motorbikes =  122  Confidences =  64.05418258905411  Motobikes average confidence =  0.5250342835168369
# Trucks =  49  Confidences =  31.024929642677307  Trucks average confidence =  0.6331618294423941
# [INFO] cleaning up...

# %%
# PLOT SCORES RESULTS

import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')

xkeys = ['Cars', 'Persons', 'Motobikes', 'Trucks']
xvalues = [carconf/carcc, personconf/personcc, motorbikeconf/motorbikecc, truckconf/truckcc]
xd = dict(zip(xkeys, xvalues))
print(xd)
print()



group_data = list(xd.values())
group_names = list(xd.keys())
group_mean = np.mean(group_data)

fig, ax = plt.subplots()
ax.set_xlim([0,1])
ax.barh(group_names, group_data)
# Out:
# {'Cars': 0.7728743673033185, 'Persons': 0.6297733210965967, 'Motobikes': 0.5250342835168369, 'Trucks': 0.6331618294423941}
# <BarContainer object of 4 artists>

# %%
# FOR TEST ONLY
#  Below NOT used because transfering data to ImageAI via drive

import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')

 
x = np.array(range(0, 1366))
y = carplot


#scatter plot for the dataset
plt.scatter(x, y)
plt.ylim([0,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f512cb4c2ae2> in <module>
#      12
#      13 #scatter plot for the dataset
# ---> 14 plt.scatter(x, y)
#      15 plt.ylim([0,1])
#      16 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size

# %%
#  This part transfer save to be load via drive in ImageAI notebook

from matplotlib import docstring
import numpy as np 
co03cv = carplot # create an array of 1000 1's for the example 
po03cv = personplot
mo03cv = motorbikeplot
to03cv = truckplot
xv03cv = xvalues

np.save('/content/drive/MyDrive/colab/var/co03cv', co03cv)

np.save('/content/drive/MyDrive/colab/var/po03cv', po03cv)
        
np.save('/content/drive/MyDrive/colab/var/mo03cv', mo03cv)
        
np.save('/content/drive/MyDrive/colab/var/to03cv', to03cv)

np.save('/content/drive/MyDrive/colab/var/xv03cv', xv03cv)

# %%
print(xv)

# %%
# FOR TEST ONLY

ci = np.load('/content/drive/MyDrive/colab/co.npy') 
print(ci)

# %%
#Tranfer timestamp to ImageAI

trans_time = time_stamp_end - time_stamp_start
file = open("/content/drive/MyDrive/colab/var/transtime03cv.txt", "w")
str = repr(trans_time)
file.write(str)
file.close()

# %%
print(str)
# Out:
# 360
